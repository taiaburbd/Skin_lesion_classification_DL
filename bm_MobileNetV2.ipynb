# %%
# Library Import
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Custom helper import
from helper.cadplot import conf_matrix
from helper.utils import log_results, plot_training_history,evaluate_model

# %%
# Trial run for mini dataset due to processing times.
trail_run = True

# %%
# Path Define
# File prefix name
_prefix = ''
_datapath="/Users/taiaburrahman/Desktop/Udg/CADx/Challenge/tf/"
# Set the path to your datasets
if trail_run:
    path = _datapath + "trial_dataset/binary/"
    _prefix = "trail_"
else:
    path = _datapath + "dataset/binary/"
    _prefix = "final_"

TRAIN_DATA_DIR = path + 'train'
VALIDATION_DATA_DIR = path + 'val'
TEST_DATA_DIR = path + 'testX'

# %%
# Set a random seed for reproducibility
seed_value = 42
tf.random.set_seed(seed_value)

# %%
# Helper function

# Save model 
def model_save(model,file_path):
    model.save(file_path)

# %%
# Create a DataFrame for the test data
test_df = pd.DataFrame({'filename': os.listdir(TEST_DATA_DIR), 'class': None})
test_df['class'] = 0  # You can set a default class label for all test images (e.g., 0)

# %%
# Model Param setup
# Image dimensions
img_width, img_height = 224, 224
input_shape = (img_width, img_height, 3)
# Batch size
batch_size = 32
# Iteration
EPOCHS = 20

# %%
# Use ImageDataGenerator for data augmentation and normalization
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=90,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.2  # 20% of the data will be used for validation
)
# Use ImageDataGenerator for testing without data augmentation
test_datagen = ImageDataGenerator(rescale=1.0/255)
# Create a data generator for training (with validation split)
train_generator = train_datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=True,
    class_mode='binary',
    subset='training'  # specify that this is the training set
)

# Create a data generator for validation (with validation split)
validation_generator = train_datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    color_mode='rgb',
    shuffle=True,
    class_mode='binary',
    subset='validation'  # specify that this is the validation set
)

test_generator = test_datagen.flow_from_directory(
    VALIDATION_DATA_DIR,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 82 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# Found 102 images belonging to 2 classes.

# %%
prefix = _prefix + 'MobileNetV2_'

# Load the pre-trained MobileNetV2 model
mobilenetv2_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))

# Freeze the convolutional layers of MobileNetV2
for layer in mobilenetv2_model.layers:
    layer.trainable = False

# Create a new model with MobileNetV2 and additional layers for binary classification
mobilenetv2_custom_model = Sequential()
mobilenetv2_custom_model.add(mobilenetv2_model)
mobilenetv2_custom_model.add(Flatten())
mobilenetv2_custom_model.add(Dense(128, activation='relu'))
mobilenetv2_custom_model.add(Dense(1, activation='sigmoid'))

# Model summary
mobilenetv2_custom_model.summary()

# Compile the MobileNetV2 custom model
mobilenetv2_custom_model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the MobileNetV2 custom model
start_time = time.time()

history_mobilenetv2_custom = mobilenetv2_custom_model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator
)
end_time = time.time()
# Save the VGG16 custom model (modify the saving path)
model_save(mobilenetv2_custom_model, f'model/{prefix}_model.h5')
# Out:
# 2023-12-12 22:13:46.582413: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2023-12-12 22:13:46.582437: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-12-12 22:13:46.582444: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-12-12 22:13:46.582906: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-12-12 22:13:46.583255: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 128)               8028288
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 10286401 (39.24 MB)
# Trainable params: 8028417 (30.63 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/20
# 2023-12-12 22:13:50.235293: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2023-12-12 22:13:50.332784: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 3/3 [==============================] - 6s 1s/step - loss: 32.5704 - accuracy: 0.5244 - val_loss: 3.7909 - val_accuracy: 0.8500
# Epoch 2/20
# 3/3 [==============================] - 2s 511ms/step - loss: 11.0915 - accuracy: 0.7317 - val_loss: 47.5768 - val_accuracy: 0.5500
# Epoch 3/20
# 3/3 [==============================] - 2s 502ms/step - loss: 34.1258 - accuracy: 0.6463 - val_loss: 65.0597 - val_accuracy: 0.5500
# Epoch 4/20
# 3/3 [==============================] - 2s 494ms/step - loss: 46.4114 - accuracy: 0.6463 - val_loss: 72.7070 - val_accuracy: 0.5500
# Epoch 5/20
# 3/3 [==============================] - 2s 630ms/step - loss: 40.1994 - accuracy: 0.6951 - val_loss: 45.7939 - val_accuracy: 0.7000
# Epoch 6/20
# 3/3 [==============================] - 1s 478ms/step - loss: 34.9224 - accuracy: 0.6585 - val_loss: 32.2399 - val_accuracy: 0.6000
# Epoch 7/20
# 3/3 [==============================] - 2s 603ms/step - loss: 21.5731 - accuracy: 0.7439 - val_loss: 29.8328 - val_accuracy: 0.6000
# Epoch 8/20
# 3/3 [==============================] - 2s 605ms/step - loss: 14.1419 - accuracy: 0.7561 - val_loss: 17.6572 - val_accuracy: 0.7500
# Epoch 9/20
# 3/3 [==============================] - 2s 498ms/step - loss: 15.4284 - accuracy: 0.7561 - val_loss: 16.2318 - val_accuracy: 0.7500
# Epoch 10/20
# 3/3 [==============================] - 1s 480ms/step - loss: 10.3655 - accuracy: 0.8049 - val_loss: 11.6960 - val_accuracy: 0.8500
# Epoch 11/20
# 3/3 [==============================] - 2s 617ms/step - loss: 10.2693 - accuracy: 0.8049 - val_loss: 10.3982 - val_accuracy: 0.9000
# Epoch 12/20
# 3/3 [==============================] - 2s 618ms/step - loss: 14.2504 - accuracy: 0.7439 - val_loss: 14.2796 - val_accuracy: 0.8000
# Epoch 13/20
# 3/3 [==============================] - 1s 472ms/step - loss: 15.5929 - accuracy: 0.7195 - val_loss: 9.7876 - val_accuracy: 0.9000
# Epoch 14/20
# 3/3 [==============================] - 2s 611ms/step - loss: 12.0246 - accuracy: 0.7439 - val_loss: 10.5895 - val_accuracy: 0.9000
# Epoch 15/20
# 3/3 [==============================] - 2s 613ms/step - loss: 10.6128 - accuracy: 0.7805 - val_loss: 17.7592 - val_accuracy: 0.8000
# Epoch 16/20
# 3/3 [==============================] - 2s 496ms/step - loss: 12.4305 - accuracy: 0.7439 - val_loss: 6.7603 - val_accuracy: 0.8500
# Epoch 17/20
# 3/3 [==============================] - 2s 622ms/step - loss: 14.4336 - accuracy: 0.7683 - val_loss: 9.4597 - val_accuracy: 0.8000
# Epoch 18/20
# 3/3 [==============================] - 2s 616ms/step - loss: 11.8329 - accuracy: 0.8293 - val_loss: 21.2119 - val_accuracy: 0.8000
# Epoch 19/20
# 3/3 [==============================] - 2s 617ms/step - loss: 12.0668 - accuracy: 0.8171 - val_loss: 19.9560 - val_accuracy: 0.7500
# Epoch 20/20
# 3/3 [==============================] - 2s 609ms/step - loss: 11.8170 - accuracy: 0.7927 - val_loss: 12.0056 - val_accuracy: 0.8000
# /Users/taiaburrahman/Desktop/Udg/CADx/Challenge/tf/.venv/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
custom_model = mobilenetv2_custom_model
model_history = history_mobilenetv2_custom
# Assuming you have variables vgg16_custom_model and test_generator
test_loss, test_accuracy, conf_mat, classification_rep = evaluate_model(custom_model, test_generator)
# Assuming you have variables like start_time, end_time, test_accuracy, conf_mat, and classification_rep
log_results(prefix, start_time, end_time, test_accuracy, conf_mat, classification_rep)
print(model_history.history.keys())
# Assuming you have a variable model and prefix
plot_training_history(model_history, prefix)
# Create a heatmap for the confusion matrix
conf_matrix(conf_mat)
# Out:
# 4/4 [==============================] - 2s 330ms/step - loss: 5.6002 - accuracy: 0.9020
# 4/4 [==============================] - 2s 184ms/step
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
